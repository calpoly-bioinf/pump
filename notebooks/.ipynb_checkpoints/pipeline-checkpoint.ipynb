# %% [markdown]
# # UnderspecificationAnalysis User Guide
# The UnderspecificationAnalysis package contains methods that help to diagnose and illustrate potential model underspecification. This notebook demonstrates how to use this package along side a breast cancer subtyping dataset from METABRIC.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports
# Importing necessary libraries for processing the sample dataset and importing the UnderspecificationAnalysis class.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#@title Includes and Dependencies
from IPython.display import display, Markdown, Latex
try:
    import pump
    from pump.underspecification import PUMP
    print('Imported preinstalled pump')
except:
    import sys
    sys.path.insert(0,"../..") 
    import pump
    from pump.underspecification import PUMP
    print('Imported ../.. pump')
# Out:
# Imported ../.. pump

# %%
import pandas as pd

# %% [markdown]
# ## Data Processing
# Loading and pre-processing the lung cancer diagnosis dataset from TCGA. The labels were manually added in prior to loading into this notebook, so the method to extract the labels is not traditional. We also want to make sure all entries are valid, so we need the complete dataset Xy along with the separate X and y for later use.

# %%
import pandas as pd
url='https://drive.google.com/file/d/1J5lnmAVUbMXQuODLdFF19Bl_YAqPzAXj/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url,sep='\t')
#df = pd.read_csv('brca_metabric_clinical_data.tsv',sep='\t')
df = df.loc[df['Pam50 + Claudin-low subtype']!='NC']
df.set_index('Sample ID',inplace=True)

# %%
urls=[
    "https://drive.google.com/file/d/10QpYL1ZWW7ljqsCSeXKX9ZO30B73uHuM/view?usp=share_link",
    "https://drive.google.com/file/d/1JE0KkTx9mSSrdfNwISiEXX2aLSq-GmrJ/view?usp=share_link",
    "https://drive.google.com/file/d/18tgo-o_-qPCVSjuBEPVrbphrA-Hbi4D9/view?usp=share_link",
    "https://drive.google.com/file/d/1SYa5E5UU6a8H6dY4yrk3QDfHKRQOLigm/view?usp=share_link",
    "https://drive.google.com/file/d/1627jeYR6m1m33qnFxvgeAezp91GiR6PM/view?usp=share_link"
    "https://drive.google.com/file/d/1ydv5JLmtZ-CjZuE0raaSITwOwvN5Hzql/view?usp=share_link",
    "https://drive.google.com/file/d/1aKkviqXT2-zDCvEFCwut_ixE1w5E54iO/view?usp=share_link",
    "https://drive.google.com/file/d/1lQvm8dO6QkM8Rtl3q54YLV8rgVyDuwQu/view?usp=share_link",
    "https://drive.google.com/file/d/15EbQti2sF-TzD606fkUCw4B8gII1oB_p/view?usp=share_link",
    "https://drive.google.com/file/d/1XPu2BylAMoQP7olPDCQX6Y9jBbXb5g-S/view?usp=share_link",
    "https://drive.google.com/file/d/1ZeBGGn3YqfSqweWQqcW1gKXBj2kY_ELQ/view?usp=share_link",
    "https://drive.google.com/file/d/1J_dHQOsegjmN_nylscCVSHCZeyZWFLoi/view?usp=share_link",
    "https://drive.google.com/file/d/1LE4F7OIJrRJIsavvZKQVMt41Q2Vs_5WY/view?usp=share_link",
    "https://drive.google.com/file/d/12unnzNfBqQ-WB1vPVD-fM_LRPd8uhH7_/view?usp=share_link",
    "https://drive.google.com/file/d/1ke2hviV3WY81X-WoZg2r1TCOXehpgo-l/view?usp=share_link",
    "https://drive.google.com/file/d/1iDcHtSMJY2e3w7oufEh1yCltWp7sbAr3/view?usp=share_link",
    "https://drive.google.com/file/d/1AjMMdh_5UIojAoTUBL9KF3JoCpncLU_7/view?usp=share_link",
    "https://drive.google.com/file/d/1V8YXJstjrQv6p7zTwzuFU42V8kL6utfT/view?usp=share_link",
    "https://drive.google.com/file/d/1NdWS49_No9unD9Rm7bWr8JVJ14NGSgbO/view?usp=share_link",
    "https://drive.google.com/file/d/1llGTAWM8vuirS_TX-Hvv4mq7snYrJvAl/view?usp=share_link",
    "https://drive.google.com/file/d/1xsL-fEq0PXw_B_jEAVkf4HkMk-m0BA5f/view?usp=share_link",
    "https://drive.google.com/file/d/1zm-IhmDpziYwM8ceh2daMQkatSmE2Xv7/view?usp=share_link"
]

# %%
Xs = []
columns = None
for url in urls:
    url='https://drive.google.com/uc?id=' + url.split('/')[-2]
    if columns is None:
        X = pd.read_csv(url)
        columns = X.columns
    else:
        X = pd.read_csv(url,header=None,columns=columns)
    X.set_index('Sample ID',inplace=True)
    Xs.append(X)

X = pd.concat(Xs, axis=0)
X.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_257126/1136705896.py in <module>
#       3     url='https://drive.google.com/uc?id=' + url.split('/')[-2]
#       4     X = pd.read_csv(url)
# ----> 5     X.set_index('Sample ID',inplace=True)
#       6     Xs.append(X)
#       7
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Sample ID'] are in the columns"

# %%
y = df['Pam50 + Claudin-low subtype']
Xy = X.join(y).dropna()
X = Xy.drop(['Pam50 + Claudin-low subtype'], axis=1)
y = Xy['Pam50 + Claudin-low subtype']
Xy
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_257126/985555967.py in <module>
#       1 X = pd.read_csv('/large/metabric/expression_with_gene_ids_min_max_no_pam50.csv.gz')
#       2 X.set_index('Sample ID',inplace=True)
# ----> 3 df = pd.read_csv('brca_metabric_clinical_data.tsv',sep='\t')
#       4 df = df.loc[df['Pam50 + Claudin-low subtype']!='NC']
#       5 df.set_index('Sample ID',inplace=True)
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.local/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'brca_metabric_clinical_data.tsv'

# %% [markdown]
# ## Initializing PUMP
# Since PUMP is a Python library, this is a typical way to initialize the class. We set the general data directory to be 'data/'

# %%
pump = PUMP(output_dir='data')

# %% [markdown]
# ## Data Analysis
# After multiple trials, we believe this run with these parameters produces a generally decent cluster analysis on the dataset. These parameters will be utilized for shifting the datasets afterwards. Upon viewing the output files in data/data_analysis, we concluded that having 3 clusters on HER2 was a good way to separate the data points.

# %%
Xy_filtered = pump.analyze_dataset(X, y, methods=['clustering'], cluster_focus='Her2', subdirectory='data_analysis', num_clusters=3)
# Out:
# Running PCA Analysis ...
# Running K-means Analysis ...
# Writing Cluster Analysis ...
# -----[ COMPLETE ]-----
# Check /data/data_analysis for the results.

# %% [markdown]
# ## Shifted Stress Testing
# Knowing that we prefer the 3 clusters on HER2, we want to create shifted datasets around HER2 to stress test models. We choose to have 50 shifted sets per cluster and an 80-20 train-test split (70-10 for train-val). The datasets can be viewed in 'data/indices'.

# %%
pump.create_shifted_datasets(X, y, Xy_filtered,
                             num_clusters=3,
                             shift_type='clustering',
                             split_ratio=[0.7,0.1,0.2],
                             cluster_focus='Her2',
                             subdirectory='indices',
                             num_shifted_sets=50
)
# Out:
# Creating shifted sets ...
# Writing out sets ...
# -----[ COMPLETE ]-----
# Check /data/indices for the results.

# %% [markdown]
# ## Performance Evaluation
# PUMP provides a variety of options in terms of evaluating performances on shifted datasets. Currently, PUMP supports the following models:
# * SVM: (Linear) Supoprt Vector Machines
# * RF: Random Forest
# * MLP: Neural Network (Multi-Layer Perceptron)
#
# For the purpose of this notebook, we will train on Random Forest with random states 0-2. The performance metrics can be viewed in 'data/results/'.

# %%
pump.evaluate_shifted_sets(X, y, subdirectory='results', models=['rf'], random_states=[0, 1, 2])
# Out:
# Evaluating models ...
#     Evaluating: data/indices/1,True/index_df_14.csv
#     Evaluating: data/indices/1,True/index_df_46.csv
#     Evaluating: data/indices/1,True/index_df_49.csv
#     Evaluating: data/indices/1,True/index_df_6.csv
#     Evaluating: data/indices/1,True/index_df_11.csv
#     Evaluating: data/indices/1,True/index_df_9.csv
#     Evaluating: data/indices/1,True/index_df_30.csv
#     Evaluating: data/indices/1,True/index_df_34.csv
#     Evaluating: data/indices/1,True/index_df_47.csv
#     Evaluating: data/indices/1,True/index_df_28.csv
#     Evaluating: data/indices/1,True/index_df_3.csv
#     Evaluating: data/indices/1,True/index_df_17.csv
#     Evaluating: data/indices/1,True/index_df_41.csv
#     Evaluating: data/indices/1,True/index_df_31.csv
#     Evaluating: data/indices/1,True/index_df_45.csv
#     Evaluating: data/indices/1,True/index_df_32.csv
#     Evaluating: data/indices/1,True/index_df_18.csv
#     Evaluating: data/indices/1,True/index_df_36.csv
#     Evaluating: data/indices/1,True/index_df_21.csv
#     Evaluating: data/indices/1,True/index_df_20.csv
#     Evaluating: data/indices/1,True/index_df_16.csv
#     Evaluating: data/indices/1,True/index_df_15.csv
#     Evaluating: data/indices/1,True/index_df_1.csv
#     Evaluating: data/indices/1,True/index_df_38.csv
#     Evaluating: data/indices/1,True/index_df_37.csv
#     Evaluating: data/indices/1,True/index_df_25.csv
#     Evaluating: data/indices/1,True/index_df_7.csv
#     Evaluating: data/indices/1,True/index_df_22.csv
#     Evaluating: data/indices/1,True/index_df_0.csv
#     Evaluating: data/indices/1,True/index_df_24.csv
#     Evaluating: data/indices/1,True/index_df_40.csv
#     Evaluating: data/indices/1,True/index_df_35.csv
#     Evaluating: data/indices/1,True/index_df_2.csv
#     Evaluating: data/indices/1,True/index_df_4.csv
#     Evaluating: data/indices/1,True/index_df_43.csv
#     Evaluating: data/indices/1,True/index_df_27.csv
#     Evaluating: data/indices/1,True/index_df_44.csv
#     Evaluating: data/indices/1,True/index_df_12.csv
#     Evaluating: data/indices/1,True/index_df_42.csv
#     Evaluating: data/indices/2,True/index_df_46.csv
#     Evaluating: data/indices/2,True/index_df_49.csv
#     Evaluating: data/indices/2,True/index_df_6.csv
#     Evaluating: data/indices/2,True/index_df_11.csv
#     Evaluating: data/indices/2,True/index_df_9.csv
#     Evaluating: data/indices/2,True/index_df_30.csv
#     Evaluating: data/indices/2,True/index_df_34.csv
#     Evaluating: data/indices/2,True/index_df_47.csv
#     Evaluating: data/indices/2,True/index_df_28.csv
#     Evaluating: data/indices/2,True/index_df_3.csv
#     Evaluating: data/indices/2,True/index_df_17.csv
#     Evaluating: data/indices/2,True/index_df_41.csv
#     Evaluating: data/indices/2,True/index_df_31.csv
#     Evaluating: data/indices/2,True/index_df_45.csv
#     Evaluating: data/indices/2,True/index_df_32.csv
#     Evaluating: data/indices/2,True/index_df_18.csv
#     Evaluating: data/indices/2,True/index_df_36.csv
#     Evaluating: data/indices/2,True/index_df_21.csv
#     Evaluating: data/indices/2,True/index_df_20.csv
#     Evaluating: data/indices/2,True/index_df_16.csv
#     Evaluating: data/indices/2,True/index_df_15.csv
#     Evaluating: data/indices/2,True/index_df_1.csv
#     Evaluating: data/indices/2,True/index_df_38.csv
#     Evaluating: data/indices/2,True/index_df_37.csv
#     Evaluating: data/indices/2,True/index_df_25.csv
#     Evaluating: data/indices/2,True/index_df_7.csv
#     Evaluating: data/indices/2,True/index_df_22.csv
#     Evaluating: data/indices/2,True/index_df_0.csv
#     Evaluating: data/indices/2,True/index_df_24.csv
#     Evaluating: data/indices/2,True/index_df_40.csv
#     Evaluating: data/indices/2,True/index_df_35.csv
#     Evaluating: data/indices/2,True/index_df_2.csv
#     Evaluating: data/indices/2,True/index_df_4.csv
#     Evaluating: data/indices/2,True/index_df_43.csv
#     Evaluating: data/indices/2,True/index_df_27.csv
#     Evaluating: data/indices/2,True/index_df_44.csv
#     Evaluating: data/indices/2,True/index_df_12.csv
#     Evaluating: data/indices/2,True/index_df_42.csv
#     Evaluating: data/indices/2,True/index_df_26.csv
#     Evaluating: data/indices/2,True/index_df_33.csv
#     Evaluating: data/indices/2,True/index_df_29.csv
#     Evaluating: data/indices/2,True/index_df_23.csv
#     Evaluating: data/indices/2,True/index_df_5.csv
#     Evaluating: data/indices/2,True/index_df_10.csv
#     Evaluating: data/indices/2,True/index_df_19.csv
#     Evaluating: data/indices/2,True/index_df_39.csv
#     Evaluating: data/indices/2,True/index_df_48.csv
#     Evaluating: data/indices/2,True/index_df_8.csv
#     Evaluating: data/indices/2,True/index_df_13.csv
#     Evaluating: data/indices/0,True/index_df_14.csv
#     Evaluating: data/indices/0,True/index_df_46.csv
#     Evaluating: data/indices/0,True/index_df_49.csv
#     Evaluating: data/indices/0,True/index_df_6.csv
#     Evaluating: data/indices/0,True/index_df_11.csv
#     Evaluating: data/indices/0,True/index_df_9.csv
#     Evaluating: data/indices/0,True/index_df_30.csv
#     Evaluating: data/indices/0,True/index_df_34.csv
#     Evaluating: data/indices/0,True/index_df_47.csv
#     Evaluating: data/indices/0,True/index_df_28.csv
#     Evaluating: data/indices/0,True/index_df_3.csv
#     Evaluating: data/indices/0,True/index_df_17.csv
#     Evaluating: data/indices/0,True/index_df_41.csv
#     Evaluating: data/indices/0,True/index_df_31.csv
#     Evaluating: data/indices/0,True/index_df_45.csv
#     Evaluating: data/indices/0,True/index_df_32.csv
#     Evaluating: data/indices/0,True/index_df_18.csv
#     Evaluating: data/indices/0,True/index_df_36.csv
#     Evaluating: data/indices/0,True/index_df_21.csv
#     Evaluating: data/indices/0,True/index_df_20.csv
#     Evaluating: data/indices/0,True/index_df_16.csv
#     Evaluating: data/indices/0,True/index_df_15.csv
#     Evaluating: data/indices/0,True/index_df_1.csv
#     Evaluating: data/indices/0,True/index_df_38.csv
#     Evaluating: data/indices/0,True/index_df_37.csv
#     Evaluating: data/indices/0,True/index_df_25.csv
#     Evaluating: data/indices/0,True/index_df_7.csv
#     Evaluating: data/indices/0,True/index_df_22.csv
#     Evaluating: data/indices/0,True/index_df_0.csv
#     Evaluating: data/indices/0,True/index_df_24.csv
#     Evaluating: data/indices/0,True/index_df_40.csv
#     Evaluating: data/indices/0,True/index_df_35.csv
#     Evaluating: data/indices/0,True/index_df_2.csv
#     Evaluating: data/indices/0,True/index_df_4.csv
#     Evaluating: data/indices/0,True/index_df_43.csv
#     Evaluating: data/indices/0,True/index_df_27.csv
#     Evaluating: data/indices/0,True/index_df_44.csv
#     Evaluating: data/indices/0,True/index_df_12.csv
#     Evaluating: data/indices/0,True/index_df_42.csv
#     Evaluating: data/indices/0,True/index_df_26.csv
#     Evaluating: data/indices/0,True/index_df_33.csv
#     Evaluating: data/indices/0,True/index_df_29.csv
#     Evaluating: data/indices/0,True/index_df_23.csv
#     Evaluating: data/indices/0,True/index_df_5.csv
#     Evaluating: data/indices/0,True/index_df_10.csv
#     Evaluating: data/indices/0,True/index_df_19.csv
#     Evaluating: data/indices/0,True/index_df_39.csv
#     Evaluating: data/indices/0,True/index_df_48.csv
#     Evaluating: data/indices/0,True/index_df_8.csv
#     Evaluating: data/indices/0,True/index_df_13.csv
#     Evaluating: data/indices/2,False/index_df_14.csv
#     Evaluating: data/indices/2,False/index_df_46.csv
#     Evaluating: data/indices/2,False/index_df_49.csv
#     Evaluating: data/indices/2,False/index_df_6.csv
#     Evaluating: data/indices/2,False/index_df_11.csv
#     Evaluating: data/indices/2,False/index_df_9.csv
#     Evaluating: data/indices/2,False/index_df_30.csv
#     Evaluating: data/indices/2,False/index_df_34.csv
#     Evaluating: data/indices/2,False/index_df_47.csv
#     Evaluating: data/indices/2,False/index_df_28.csv
#     Evaluating: data/indices/2,False/index_df_3.csv
#     Evaluating: data/indices/2,False/index_df_17.csv
#     Evaluating: data/indices/2,False/index_df_41.csv
#     Evaluating: data/indices/2,False/index_df_31.csv
#     Evaluating: data/indices/2,False/index_df_45.csv
#     Evaluating: data/indices/2,False/index_df_32.csv
#     Evaluating: data/indices/2,False/index_df_18.csv
#     Evaluating: data/indices/2,False/index_df_36.csv
#     Evaluating: data/indices/2,False/index_df_21.csv
#     Evaluating: data/indices/2,False/index_df_20.csv
#     Evaluating: data/indices/2,False/index_df_16.csv
#     Evaluating: data/indices/2,False/index_df_15.csv
#     Evaluating: data/indices/2,False/index_df_1.csv
#     Evaluating: data/indices/2,False/index_df_38.csv
#     Evaluating: data/indices/2,False/index_df_37.csv
#     Evaluating: data/indices/2,False/index_df_25.csv
#     Evaluating: data/indices/2,False/index_df_7.csv
#     Evaluating: data/indices/2,False/index_df_22.csv
#     Evaluating: data/indices/2,False/index_df_0.csv
#     Evaluating: data/indices/2,False/index_df_24.csv
#     Evaluating: data/indices/2,False/index_df_40.csv
#     Evaluating: data/indices/2,False/index_df_35.csv
#     Evaluating: data/indices/2,False/index_df_2.csv
#     Evaluating: data/indices/2,False/index_df_4.csv
#     Evaluating: data/indices/2,False/index_df_43.csv
#     Evaluating: data/indices/2,False/index_df_27.csv
#     Evaluating: data/indices/2,False/index_df_44.csv
#     Evaluating: data/indices/2,False/index_df_12.csv
#     Evaluating: data/indices/2,False/index_df_42.csv
#     Evaluating: data/indices/2,False/index_df_26.csv
#     Evaluating: data/indices/2,False/index_df_33.csv
#     Evaluating: data/indices/2,False/index_df_29.csv
#     Evaluating: data/indices/2,False/index_df_23.csv
#     Evaluating: data/indices/2,False/index_df_5.csv
#     Evaluating: data/indices/2,False/index_df_10.csv
#     Evaluating: data/indices/2,False/index_df_19.csv
#     Evaluating: data/indices/2,False/index_df_39.csv
#     Evaluating: data/indices/2,False/index_df_48.csv
#     Evaluating: data/indices/2,False/index_df_8.csv
#     Evaluating: data/indices/2,False/index_df_13.csv
# Writing out results ...
# -----[ COMPLETE ]-----
# Check /data/results for the results.

# %% [markdown]
# ## Discrepancy Graphs
# To better analyze the results, let's visualize the Random Forest performances on the shifted datasets. The graphs can be viewed in 'data/results/'.

# %%
pump.plot_shifted_results(filename='rf_results.csv', subdirectory='results')

# %% [markdown]
# ## Model Selection
# Finally, we will select the top 10 models on the HER2 subtype. Note: a DataFrame is returned instead of written out.

# %%
pump.select_top_models(filename='rf_results.csv', subdirectory='results', num_models=10, class_filter='Her2')
# Out:
#             class  rep  seed cluster  avg f1-score - f1-score (unshifted)
# cluster rep
# 2       0    Her2    0    25       2                            -0.426667
#         2    Her2    2    12       2                            -0.051332
# 0       1    Her2    1     4       0                            -0.042912
#         0    Her2    0     4       0                            -0.037948
# 2       1    Her2    1     4       2                            -0.028826
# 0       2    Her2    2     4       0                            -0.026966
# 1       1    Her2    1    19       1                            -0.018457
#         2    Her2    2    19       1                            -0.014047
#         0    Her2    0    19       1                            -0.008451
